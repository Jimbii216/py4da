# %% [markdown]
# ### This program is used to generate histograms of a chosen statistic

# %% [markdown]
# ##### Importing packages

# %%
import pandas as pd
import numpy as np
import pybaseball
import os
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Setting Working Directory

# %%
print(os.getcwd())  # Check the current working directory
os.chdir("C:\\Users\\jvgas\\OneDrive\\Desktop\\learning\\github\\baseballStatistics\\py4da\\baseballStatistics\\datasets")  # Change the current working directory
print(os.getcwd())  # Verify the directory change
# Out:
# C:\Users\jvgas\OneDrive\Desktop\learning\github\baseballStatistics\py4da\baseballStatistics\datasets
# C:\Users\jvgas\OneDrive\Desktop\learning\github\baseballStatistics\py4da\baseballStatistics\datasets

# %% [markdown]
# ##### Loading in the battingData file

# %%
allBattingData = pd.read_excel('MLB Batting Data.xlsx')

# %%
allBattingData['AVG'] = allBattingData['AVG'].replace({0:np.nan})

# %%
hist = allBattingData['AVG'].hist(bins=100, color='skyblue', edgecolor='black')

plt.title('Histogram for Length Column') 
plt.xlabel('Length') 
plt.ylabel('Frequency') 

plt.show()

# %%
sns.histplot(allBattingData['AVG'], bins = 100, kde=True, color='lightgreen', edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Density')
plt.title('2024 MLB Batting AVG Histogram with Density Plot')
# Out:
# Text(0.5, 1.0, '2024 MLB Batting AVG Histogram with Density Plot')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
 
axes[0].hist(allBattingData['AVG'], bins=100, color='Yellow', edgecolor='black')
axes[0].set_title('2024 MLB Batting Average')
 
axes[1].hist(allBattingData['HR'], bins=50, color='Pink', edgecolor='black')
axes[1].set_title('2024 MLB Home Runs')
 
# Adding labels and title
for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')
 
# Adjusting layout for better spacing
plt.tight_layout()
 
# Display the figure
plt.show()

Out
# Out:
# {7:      Unnamed: 0   IDfg  Season              Name   Team  Age    G   AB   PA  \
#  0             4  15640    2024       Aaron Judge    NYY   32  158  559  704
#  1            13  25764    2024    Bobby Witt Jr.    KCR   24  161  636  709
#  2             8  19755    2024     Shohei Ohtani    LAD   29  159  636  731
#  3             9  20123    2024         Juan Soto    NYY   25  157  576  713
#  4            29  26289    2024  Gunnar Henderson    BAL   23  159  630  719
#  ..          ...    ...     ...               ...    ...  ...  ...  ...  ...
#  646         592   6887    2024  Martin Maldonado    CHW   37   48  135  147
#  647         605  15676    2024        Jose Abreu    HOU   37   35  113  120
#  648         494  20543    2024  Elehuris Montero    COL   25   67  224  247
#  649         544  12155    2024     Eddie Rosario  - - -   32   91  297  319
#  650         562  11615    2024     Brandon Drury    LAA   31   97  325  360
#
#         H  ...   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG
#  0    180  ...  133   20  171    9   2   0   22  10   0  0.322
#  1    211  ...   57    9  106    8   8   0    4  31  12  0.332
#  2    197  ...   81   10  162    6   5   0    7  59   4  0.310
#  3    166  ...  129    2  119    4   4   0   10   7   4  0.288
#  4    177  ...   78    1  159    7   4   0    2  21   4  0.281
#  ..   ...  ...  ...  ...  ...  ...  ..  ..  ...  ..  ..    ...
#  646   16  ...    8    0   51    1   0   3    5   0   0  0.119
#  647   14  ...    4    0   28    2   1   0    4   0   0  0.124
#  648   46  ...   20    0   56    0   3   0    7   0   0  0.205
#  649   52  ...   16    0   77    0   4   2    4   9   1  0.175
#  650   55  ...   27    0   81    5   3   0   13   1   0  0.169
#
#  [651 rows x 26 columns],
#  16: Text(17.200000000000003, 0.5, 'Frequency'),
#  22: <AxesSubplot:ylabel='Count'>,
#  23: <AxesSubplot:xlabel='AVG', ylabel='Count'>,
#  24: <AxesSubplot:xlabel='AVG', ylabel='Count'>,
#  25: <AxesSubplot:xlabel='AVG', ylabel='Count'>,
#  26: Text(0.5, 1.0, 'Customized Histogram with Density Plot'),
#  27: Text(0.5, 1.0, '2024 MLB Batting AVG Histogram with Density Plot')}
