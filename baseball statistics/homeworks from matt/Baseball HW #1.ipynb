# %% [markdown]
# This is a program to create and merge players' stats into one DataFrame

# %% [markdown]
# Importing packages

# %%
import statsapi
import pandas as pd

# %% [markdown]
# Brett Anderson

# %%
playerName = 'Brett Anderson'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear') ## uses 'id' as personId, 'hitting' as group, and 'yearByYear' for type (can use: 'career', 'season', and 'yearByYear'). Creates a dictionary called 'response' and sets it equally to statsapi.player_stat_data.

df = pd.DataFrame.from_records(response) ## Converts dict[response] to df.response using pandas .from_records
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfBrettAnderson = pd.DataFrame(df)

dfBrettAnderson = dfBrettAnderson.join(pd.json_normalize(dfBrettAnderson['stats_y'])).drop('stats_y', axis = 'columns')

dfBrettAnderson = dfBrettAnderson.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                         'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                         'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                         'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                         'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                         'atBatsPerHomeRun'], axis=1)

dfBrettAnderson = dfBrettAnderson.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Frank Catalanotto

# %%
playerName = 'Frank Catalanotto'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfFrankCatalanotto = pd.DataFrame(df)

dfFrankCatalanotto = dfFrankCatalanotto.join(pd.json_normalize(dfFrankCatalanotto['stats_y'])).drop('stats_y', axis = 'columns')

dfFrankCatalanotto = dfFrankCatalanotto.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfFrankCatalanotto = dfFrankCatalanotto.sort_values(by = 'season', ascending = True)

# %%
df
# Out:
#     active bat_side   current_team first_name      id    last_name  \
# 0    False     Left  New York Mets      Frank  112131  Catalanotto
# 1    False     Left  New York Mets      Frank  112131  Catalanotto
# 2    False     Left  New York Mets      Frank  112131  Catalanotto
# 3    False     Left  New York Mets      Frank  112131  Catalanotto
# 4    False     Left  New York Mets      Frank  112131  Catalanotto
# 5    False     Left  New York Mets      Frank  112131  Catalanotto
# 6    False     Left  New York Mets      Frank  112131  Catalanotto
# 7    False     Left  New York Mets      Frank  112131  Catalanotto
# 8    False     Left  New York Mets      Frank  112131  Catalanotto
# 9    False     Left  New York Mets      Frank  112131  Catalanotto
# 10   False     Left  New York Mets      Frank  112131  Catalanotto
# 11   False     Left  New York Mets      Frank  112131  Catalanotto
# 12   False     Left  New York Mets      Frank  112131  Catalanotto
# ...

# %% [markdown]
# Frankie De La Cruz

# %%
playerName = 'Frankie De La Cruz'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfFrankieDeLaCruz = pd.DataFrame(df)

dfFrankieDeLaCruz = dfFrankieDeLaCruz.join(pd.json_normalize(dfFrankieDeLaCruz['stats_y'])).drop('stats_y', axis = 'columns')

dfFrankieDeLaCruz = dfFrankieDeLaCruz.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfFrankieDeLaCruz = dfFrankieDeLaCruz.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Frank Francisco

# %%
playerName = 'Frank Francisco'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfFrankFrancisco = pd.DataFrame(df)

dfFrankFrancisco = dfFrankFrancisco.join(pd.json_normalize(dfFrankFrancisco['stats_y'])).drop('stats_y', axis = 'columns')

dfFrankFrancisco = dfFrankFrancisco.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfFrankFrancisco = dfFrankFrancisco.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Ryan Franklin

# %%
playerName = 'Ryan Franklin'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfRyanFranklin = pd.DataFrame(df)

dfRyanFranklin = dfRyanFranklin.join(pd.json_normalize(dfRyanFranklin['stats_y'])).drop('stats_y', axis = 'columns')

dfRyanFranklin = dfRyanFranklin.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfRyanFranklin = dfRyanFranklin.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Franklin Gutierrez

# %%
playerName = 'Franklin Gutierrez'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfFranklinGutierrez = pd.DataFrame(df)

dfFranklinGutierrez = dfFranklinGutierrez.join(pd.json_normalize(dfFranklinGutierrez['stats_y'])).drop('stats_y', axis = 'columns')

dfFranklinGutierrez = dfFranklinGutierrez.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfFranklinGutierrez = dfFranklinGutierrez.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Franklin Morales

# %%
playerName = 'Franklin Morales'
year = '2009'
player = statsapi.lookup_player(playerName, season = year)

##

id = player[0].get('id')

##

response = statsapi.player_stat_data(id, group = 'hitting', type = 'yearByYear')

df = pd.DataFrame.from_records(response)
df = pd.merge(df, df['stats'].apply(pd.Series), left_index = True, right_index = True).drop(columns = 'stats_x')

##

dfFranklinMorales = pd.DataFrame(df)

dfFranklinMorales = dfFranklinMorales.join(pd.json_normalize(dfFranklinMorales['stats_y'])).drop('stats_y', axis = 'columns')

dfFranklinMorales = dfFranklinMorales.drop(['active', 'bat_side', 'current_team', 'id', 'last_played', 'mlb_debut', 'nickname', 'pitch_hand',
                        'position','type', 'group', 'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles',
                        'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch',
                        'atBats', 'obp', 'slg', 'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage', 
                        'groundIntoDoublePlay', 'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi', 
                        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts', 'catchersInterference', 
                        'atBatsPerHomeRun'], axis=1)

dfFranklinMorales = dfFranklinMorales.sort_values(by = 'season', ascending = True)

# %% [markdown]
# Merge all players DF

# %%
frames = [dfBrettAnderson, dfFrankCatalanotto, dfFrankieDeLaCruz, dfFrankFrancisco, dfRyanFranklin, dfFranklinGutierrez, dfFranklinMorales]
dfAll = pd.concat(frames)
dfAll
# Out:
#    first_name last_name season   avg
# 0       Brett  Anderson   2009  .000
# 1       Brett  Anderson   2011  .000
# 2       Brett  Anderson   2013  .000
# 3       Brett  Anderson   2014  .143
# 4       Brett  Anderson   2015  .085
# ..        ...       ...    ...   ...
# 7    Franklin   Morales   2012  .500
# 8    Franklin   Morales   2013  .000
# 9    Franklin   Morales   2014  .100
# 10   Franklin   Morales   2015  .000
# 11   Franklin   Morales   2016  .000
#
# [73 rows x 4 columns]
